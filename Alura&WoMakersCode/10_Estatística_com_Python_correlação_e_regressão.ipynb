# %% [markdown]
# <a href="https://colab.research.google.com/github/crislanecas/estudos_python/blob/main/Alura%26WoMakersCode/10_Estat%C3%ADstica_com_Python_correla%C3%A7%C3%A3o_e_regress%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color=green size=10>CURSO DE ESTATÍSTICA - PARTE 4</font>
# ***

# %% [markdown]
# # <font color=green>1 CONHECENDO OS DADOS</font>
# ***

# %% [markdown]
# ## <font color=green>1.1 Dataset do projeto</font>
# ***

# %% [markdown]
# ### Pesquisa Nacional por Amostra de Domicílios - 2015
#
# A <b>Pesquisa Nacional por Amostra de Domicílios - PNAD</b> investiga anualmente, de forma permanente, características gerais da população, de educação, trabalho, rendimento e habitação e outras, com periodicidade variável, de acordo com as necessidades de informação para o país, como as características sobre migração, fecundidade, nupcialidade, saúde, segurança alimentar, entre outros temas. O levantamento dessas estatísticas constitui, ao longo dos 49 anos de realização da pesquisa, um importante instrumento para formulação, validação e avaliação de políticas orientadas para o desenvolvimento socioeconômico e a melhoria das condições de vida no Brasil.

# %% [markdown]
# ### Fonte dos Dados
#
# https://ww2.ibge.gov.br/home/estatistica/populacao/trabalhoerendimento/pnad2015/microdados.shtm

# %% [markdown]
# ### Variáveis utilizadas
#
# > ### Renda
# > ***
#
# Rendimento mensal do trabalho principal para pessoas de 10 anos ou mais de idade.
#
# > ### Idade
# > ***
#
# Idade do morador na data de referência em anos.
#
# > ### Altura (elaboração própria)
# > ***
#
# Altura do morador em metros.
#
# > ### UF
# > ***
#
# |Código|Descrição|
# |---|---|
# |11|Rondônia|
# |12|Acre|
# |13|Amazonas|
# |14|Roraima|
# |15|Pará|
# |16|Amapá|
# |17|Tocantins|
# |21|Maranhão|
# |22|Piauí|
# |23|Ceará|
# |24|Rio Grande do Norte|
# |25|Paraíba|
# |26|Pernambuco|
# |27|Alagoas|
# |28|Sergipe|
# |29|Bahia|
# |31|Minas Gerais|
# |32|Espírito Santo|
# |33|Rio de Janeiro|
# |35|São Paulo|
# |41|Paraná|
# |42|Santa Catarina|
# |43|Rio Grande do Sul|
# |50|Mato Grosso do Sul|
# |51|Mato Grosso|
# |52|Goiás|
# |53|Distrito Federal|
#
# > ### Sexo
# > ***
#
# |Código|Descrição|
# |---|---|
# |0|Masculino|
# |1|Feminino|
#
# > ### Anos de Estudo
# > ***
#
# |Código|Descrição|
# |---|---|
# |1|Sem instrução e menos de 1 ano|
# |2|1 ano|
# |3|2 anos|
# |4|3 anos|
# |5|4 anos|
# |6|5 anos|
# |7|6 anos|
# |8|7 anos|
# |9|8 anos|
# |10|9 anos|
# |11|10 anos|
# |12|11 anos|
# |13|12 anos|
# |14|13 anos|
# |15|14 anos|
# |16|15 anos ou mais|
# |17|Não determinados|
# ||Não aplicável|
#
# > ### Cor
# > ***
#
# |Código|Descrição|
# |---|---|
# |0|Indígena|
# |2|Branca|
# |4|Preta|
# |6|Amarela|
# |8|Parda|
# |9|Sem declaração|

# %% [markdown]
# #### <font color='red'>Observação</font>
# ***
# > Os seguintes tratamentos foram realizados nos dados originais:
# > 1. Foram eliminados os registros onde a <b>Renda</b> era inválida (999 999 999 999);
# > 2. Foram eliminados os registros onde a <b>Renda</b> era missing;
# > 3. Foram considerados somente os registros das <b>Pessoas de Referência</b> de cada domicílio (responsável pelo domicílio).

# %% [markdown]
# ### Solução do problema com dependência do statsmodels

# %%
# Retire o comentário da linha de código abaixo caso precise fazer a correção.
# !pip install scipy==1.2 --upgrade

# %% [markdown]
# ### Importando bibliotecas
#
# https://pandas.pydata.org/
#
# https://www.numpy.org/
#
# https://seaborn.pydata.org/

# %%
# Importa bibliotecas.
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Lendo o dataset do projeto

# %%
# Importa parte da biblioteca do Google Colab para te acesso ao Google Drive, utilizando o método drive.mount().
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cria um dataframe para receber os dados do arquivo CSV.
dados = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Bootcamp Data Analytics - WoMakersCode/Estatística - Alura/00. Dados/dados.csv')

# %% [markdown]
# ---

# %% [markdown]
# # <font color=green>2 RODANDO UMA REGRESSÃO LINEAR</font>
# ***

# %% [markdown]
# ## Dataset de exemplo
# > ### $Y$ = Gasto das famílias
# > ### $X$ = Renda das Famílias

# %%
# Cria uma dicionário com duas listas de dados, com gasto e renda famíliar.
dataset = {
    'Y': [3011, 1305, 1879, 2654, 2849, 1068, 2892, 2543, 3074, 849, 2184, 2943, 1357, 2755, 2163, 3099, 1600, 353, 1778, 740, 2129, 3302, 2412, 2683, 2515, 2395, 2292, 1000, 600, 1864, 3027, 1978, 2791, 1982, 900, 1964, 1247, 3067, 700, 1500, 3110, 2644, 1378, 2601, 501, 1292, 2125, 1431, 2260, 1770],
    'X': [9714, 3728, 6062, 8845, 8378, 3338, 8507, 7947, 9915, 1632, 6825, 8918, 4100, 9184, 6180, 9997, 4500, 1069, 5925, 2466, 6083, 9712, 7780, 8383, 7185, 7483, 7640, 2100, 2000, 6012, 8902, 5345, 8210, 5662, 2700, 6546, 2900, 9894, 1500, 5000, 8885, 8813, 3446, 7881, 1164, 3401, 6641, 3329, 6648, 4800]
}

# %%
# Cria uma dataframe com os dados.
dataset = pd.DataFrame(dataset)
dataset.head()
# Out:
#       Y     X
# 0  3011  9714
# 1  1305  3728
# 2  1879  6062
# 3  2654  8845
# 4  2849  8378

# %%
# Mostra as dimensões do dataframe.
dataset.shape
# Out:
# (50, 2)

# %% [markdown]
# ### Estatísticas descritivas

# %%
# Cria um resumo estatístico do dataframe.
dataset.describe()
# Out:
#                  Y            X
# count    50.000000    50.000000
# mean   2011.120000  6065.500000
# std     817.214648  2707.187812
# min     353.000000  1069.000000
# 25%    1362.250000  3516.500000
# 50%    2127.000000  6363.000000
# 75%    2675.750000  8381.750000
# max    3302.000000  9997.000000

# %% [markdown]
# ### Análise gráfica
#
# https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %%
# Cria um gráfico boxplot com o dados do dataframe.
ax = sns.boxplot(data=dataset, orient='h', width=0.5)
ax.figure.set_size_inches(12, 6)
ax.set_title('Box plot', fontsize=20)
ax.set_xlabel('Reais (R$)', fontsize=16)
ax
# Out:
# <Axes: title={'center': 'Box plot'}, xlabel='Reais (R$)'>

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.lmplot.html

# %%
# Cria um gráfico de dispersão, com uma linha de tendência.
ax = sns.lmplot(x="X", y="Y", data=dataset)
ax.fig.set_size_inches(12, 6)
ax.fig.suptitle('Reta de Regressão - Gasto X Renda', fontsize=16, y=1.02)
ax.set_xlabels("Renda das Famílias", fontsize=14)
ax.set_ylabels("Gasto das Famílias", fontsize=14)
ax

# %% [markdown]
# ### Análise da correlação
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html

# %%
# Cria uma matriz com o calculos da correlação entre as variáveis.
dataset.corr()
# Out:
#           Y         X
# Y  1.000000  0.984835
# X  0.984835  1.000000

# %% [markdown]
# ### Modelo de regressão linear simples
#
# https://www.statsmodels.org/stable/regression.html

# %%
import statsmodels.api as sm

# %%
# Cria duas variáveis, que depois irá deixar de existir.
Y = dataset.Y
X = sm.add_constant(dataset.X)

# %%
Y.head()
# Out:
# 0    3011
# 1    1305
# 2    1879
# 3    2654
# 4    2849
# Name: Y, dtype: int64

# %%
X.head()
# Out:
#    const     X
# 0    1.0  9714
# 1    1.0  3728
# 2    1.0  6062
# 3    1.0  8845
# 4    1.0  8378

# %% [markdown]
# ### Estimando o modelo

# %%
# Cria um modelo de regressão usando o método .OLS e a função fit().
resultado_regressao = sm.OLS(Y, X).fit()

# %%
# Mostra um resumo do modelo de regressão.
print(resultado_regressao.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.970
# Model:                            OLS   Adj. R-squared:                  0.969
# Method:                 Least Squares   F-statistic:                     1547.
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           3.56e-38
# Time:                        23:55:40   Log-Likelihood:                -318.16
# No. Observations:                  50   AIC:                             640.3
# Df Residuals:                      48   BIC:                             644.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        207.9033     50.127      4.148      0.000     107.117     308.690
# ...

# %% [markdown]
# ### Obtendo as previsões dentro da amostra

# %%
# Cria uma previsão de acordo com a amostra.
dataset['Y_previsto'] = resultado_regressao.predict()
dataset
# Out:
#        Y     X   Y_previsto
# 0   3011  9714  3095.785086
# 1   1305  3728  1316.203010
# 2   1879  6062  2010.079483
# 3   2654  8845  2837.439476
# 4   2849  8378  2698.604723
# 5   1068  3338  1200.259640
# 6   2892  8507  2736.955222
# 7   2543  7947  2570.472435
# 8   3074  9915  3155.540515
# 9    849  1632   693.081721
# 10  2184  6825  2236.912280
# 11  2943  8918  2859.141696
# 12  1357  4100  1426.795147
# 13  2755  9184  2938.221020
# 14  2163  6180  2045.159784
# 15  3099  9997  3179.918352
# 16  1600  4500  1545.711423
# 17   353  1069   525.707062
# 18  1778  5925  1969.350658
# 19   740  2466   941.022158
# 20  2129  6083  2016.322587
# 21  3302  9712  3095.190505
# 22  2412  7780  2520.824890
# 23  2683  8383  2700.091176
# 24  2515  7185  2343.936929
# 25  2395  7483  2432.529554
# 26  2292  7640  2479.204193
# 27  1000  2100   832.213765
# 28   600  2000   802.484696
# 29  1864  6012  1995.214948
# 30  3027  8902  2854.385045
# 31  1978  5345  1796.922057
# ...

# %% [markdown]
# ---

# %% [markdown]
# # <font color=green>3 CORRELAÇÃO</font>
# ***

# %% [markdown]
# ## <font color=green>3.1 Covariância</font>
# ***

# %% [markdown]
# A covariância, ou variância conjunta, é a medida do grau de interdependência (ou inter-relação) numérica entre duas variáveis. É definida da seguinte maneira:

# %% [markdown]
# ### Covariância populacional
#
# # $$\sigma_{xy} = \frac 1n\sum_{i=1}^{n}(X_i-\mu_x)(Y_i-\mu_y)$$

# %% [markdown]
# ### Covariância amostral
#
# # $$S_{xy} = \frac 1{n-1}\sum_{i=1}^{n}(X_i-\bar{X})(Y_i-\bar{Y})$$

# %% [markdown]
# ### Gerando uma amostra aleatória para facilitar o entendimento

# %%
# Cria uma amostra, filtrando apenas as rendas menos que 5 mil, com 20 elementos.
amostra = dados.query('Renda < 5000').sample(n = 20, random_state = 101)

# %% [markdown]
# ### Obtendo a matriz de covariância

# %%
# Cria uma matriz com o calculo da covariância da amostra com relação aos dados/variáveis selecionadas, usando o método .cov().
amostra[['Idade', 'Renda', 'Anos de Estudo', 'Altura']].cov()
# Out:
#                       Idade          Renda  Anos de Estudo    Altura
# Idade            134.410526   -4947.968421      -16.410526  0.016506
# Renda          -4947.968421  764668.326316     2209.021053 -7.138236
# Anos de Estudo   -16.410526    2209.021053       16.936842  0.111281
# Altura             0.016506      -7.138236        0.111281  0.003354

# %% [markdown]
# ### Identificando as variâncias na diagonal principal da matriz

# %%
# Calcula a variância da variável idade, usando o método .var().
amostra.Idade.var()
# Out:
# 134.4105263157895

# %% [markdown]
# ## <font color=green>3.2 Interpretação da Covariância</font>
# ***

# %% [markdown]
# Valor de $S_{xy}$ positivo indica uma associação linear positiva entre x e y, ou seja, à medida que o valor de x aumenta, o valor de y também aumenta. Neste caso, podemos ver na figura abaixo que os pontos que têm a maior influência sobre $S_{xy}$ devem estar nos quadrantes I e III.
#
# Se o valor de $S_{xy}$ for negativo temos um indicativo de associação linear negativa entre x e y, ou seja, à medida que x aumenta, o valor de y diminui. Neste caso, podemos ver na figura abaixo que os pontos que têm a maior influência sobre $S_{xy}$ devem estar nos quadrantes II e IV.
#
# Finalmente, se os pontos estiverem uniformemente distribuídos pelos quadrantes, o valor de $S_{xy}$ se aproximará de zero, indicando que não existe nenhuma associação linear entre x e y.
#
# <img src="https://caelum-online-public.s3.amazonaws.com/1273-estatistica-parte4/01/img026.png" width=50%>

# %% [markdown]
# ### Verificando a existência de uma associação linear negativa

# %%
# Cria duas variáveis para análise.
x = amostra.Renda
y = amostra.Idade

# Cria um gráfico de dispersão para visualização das variáveis.
ax = sns.scatterplot(x = amostra.Renda, y = amostra.Idade)
ax.figure.set_size_inches(10, 6)
ax.hlines(y = y.mean(), xmin = x.min(), xmax = x.max(), colors='black', linestyles='dashed')
ax.vlines(x = x.mean(), ymin = y.min(), ymax = y.max(), colors='black', linestyles='dashed')

# %% [markdown]
# ### Verificando a existência de uma associação linear positiva

# %%
# Cria duas variáveis para análise.
# x = amostra.Renda
# y = amostra['Anos de Estudo']

# %%
# Cria um gráfico de dispersão para visualização das variáveis.
ax = sns.scatterplot(x = amostra.Renda, y = amostra['Anos de Estudo'])
ax.figure.set_size_inches(10, 6)
ax.hlines(y = y.mean(), xmin = x.min(), xmax = x.max(), colors='black', linestyles='dashed')
ax.vlines(x = x.mean(), ymin = y.min(), ymax = y.max(), colors='black', linestyles='dashed')

# %% [markdown]
# ### Verificando a inexistência de uma associação linear entre as variáveis

# %%
# Cria duas variáveis para análise.
# x = amostra.Idade
# y = amostra.Altura

# %%
# Cria um gráfico de dispersão para visualização das variáveis.
ax = sns.scatterplot(x = amostra.Idade, y = amostra.Altura)
ax.figure.set_size_inches(10, 6)
ax.hlines(y = y.mean(), xmin = x.min(), xmax = x.max(), colors='black', linestyles='dashed')
ax.vlines(x = x.mean(), ymin = y.min(), ymax = y.max(), colors='black', linestyles='dashed')

# %% [markdown]
# ### <font color='red'>Observação Importante:</font>
# > Pelo que foi apresentado pode parecer que valores elevados, tanto positivos quanto negativos, para a covariância indicam relações lineares fortes entre as variáveis envolvidas. No entanto, um problema quando se usa a covariância como uma medida da intensidade da relação linear é que o valor da covariância depende das unidades de medida para x e y.
# >
# > Uma medida da relação entre duas variáveis que não é afetada pelas unidades de medida para x e y é o coeficiente de correlação que veremos no próximo tópico.

# %% [markdown]
# ## <font color=green>3.3 Coeficiente de correlação de Pearson</font>
# ***

# %% [markdown]
# É obtido dividindo-se a covariância da população ou amostra pelo produto do desvio padrão populacional ou amostral de x pelo desvio padrão populacional ou amostral de y.
#
# O coeficiente de correlação varia de -1 a +1. Valores que se aproximam de -1 ou +1 indicam uma relação linear forte. Quanto mais próxima a correlação estiver de zero, mais fraca será a relação.
#
# Um ponto importante é que o coeficiente de correlação é uma medida de associação linear e não necessariamente de causação. Uma correlação alta entre duas variáveis não significa, necessariamente, que variações em uma delas provocará alterações na outra.

# %% [markdown]
# ### Coeficiente de correlação de Pearson - dados populacionais
#
# # $$\rho_{xy} = \frac{\sigma_{xy}}{\sigma_{x}\sigma_{y}}$$
#
# ### Coeficiente de correlação de Pearson - dados amostrais
#
# # $$r_{xy} = \frac{s_{xy}}{s_{x}s_{y}}$$
#
# Onde
#
# $\sigma_{xy}$ = covariância populacional entre x e y
#
# $s_{xy}$ = covariância amostral entre x e y
#
# $\sigma_{x}$ e $\sigma_{y}$ = desvios padrão populacionais de x e y, respectivamente
#
# $s_{x}$ e $s_{y}$ = desvios padrão amostrais de x e y, respectivamente

# %% [markdown]
# ### Obtendo $s_{xy}$

# %%
# Calcula a covariância amostral.
s_xy = dados[['Altura', 'Renda']].cov()
s_xy
# Out:
#           Altura         Renda
# Altura  0.006355 -1.078964e+00
# Renda  -1.078964  1.104491e+07

# %%
# Seleciona apenas a variância da renda.
s_xy= s_xy.Altura.loc['Renda']
s_xy
# Out:
# -1.0789639314252715

# %% [markdown]
# ### Obtendo $s_x$ e $s_y$

# %%
# Calcula o desvio padrão das variáveis.
s_x = dados.Altura.std()
s_y = dados.Renda.std()

# %% [markdown]
# ### Obtendo o coeficiente de correlação $r_{xy}$

# %%
# Calcula R, que é o coeficiente de correlação de Pearson.
r_xy = s_xy / (s_x * s_y)
r_xy
# Out:
# -0.0040726081434002874

# %% [markdown]
# ### Obtendo uma matriz de correlação com o Pandas

# %%
# Cria uma matriz com o calculo da covariância da amostra com relação aos dados/variáveis selecionadas, usando o método .cov().
dados[['Altura', 'Renda']].corr()
# Out:
#           Altura     Renda
# Altura  1.000000 -0.004073
# Renda  -0.004073  1.000000

# %%
# Cria uma matriz com o calculo da covariância da amostra com relação aos dados/variáveis selecionadas, usando o método .cov().
dados[['Altura', 'Renda']].corr()
dataset[['Y', 'X']].corr()
# Out:
#           Y         X
# Y  1.000000  0.984835
# X  0.984835  1.000000

# %%
# Cria duas variáveis para análise.
# x = amostra.Renda
# y = amostra.Altura

# %%
# Cria um gráfico de dispersão para visualização das variáveis.
ax = sns.scatterplot(x = amostra.Renda, y = amostra.Altura)
ax.figure.set_size_inches(10, 6)
ax.hlines(y = y.mean(), xmin = x.min(), xmax = x.max(), colors='black', linestyles='dashed')
ax.vlines(x = x.mean(), ymin = y.min(), ymax = y.max(), colors='black', linestyles='dashed')

# %%
# Cria duas variáveis para análise.
# x = dataset.Y
# y = dataset.X

# %%
# Cria um gráfico de dispersão para visualização das variáveis.
ax = sns.scatterplot(x = dataset.Y, y = dataset.X)
ax.figure.set_size_inches(10, 6)
ax.hlines(y = y.mean(), xmin = x.min(), xmax = x.max(), colors='black', linestyles='dashed')
ax.vlines(x = x.mean(), ymin = y.min(), ymax = y.max(), colors='black', linestyles='dashed')

# %% [markdown]
# ### Exercício - Calculando a correlação
#
# Temos o seguinte conjunto de informações sobre as variáveis X e Y:
#
# $\sigma_{xy}$ = 2.178.803,69
#
# Assinale a alternativa abaixo que apresenta o valor do coeficiente de correlação de Pearson para as variáveis X e Y.

# %%
# Variáveis envolvidas.
sigma_xy = 2178803.59
sigma_x2 = 7328865.85
sigma_y2 = 667839.78

sigma_x = np.sqrt(sigma_x2)
sigma_y= np.sqrt(sigma_y2)

# Calcula R, que é o coeficiente de correlação de Pearson.
r_xy = sigma_xy / (sigma_x * sigma_y)
r_xy
# Out:
# 0.984835179852382

# %%
# Resolução apresentada.
sigma_XY = 2178803.59
sigma_X_2 = 7328865.85
sigma_Y_2 = 667839.78

sigma_X = np.sqrt(sigma_X_2)
sigma_Y = np.sqrt(sigma_Y_2)

r_XY = sigma_XY / (sigma_X * sigma_Y)
print('Correlação ->', r_XY.round(4))
# Out:
# Correlação -> 0.9848

# %% [markdown]
# ---

# %% [markdown]
# # <font color=green>4 REGRESSÃO LINEAR</font>
# ***

# %% [markdown]
# A análise de regressão diz respeito ao estudo da dependência de uma variável (a variável dependente) em relação a uma ou mais variáveis, as variáveis explicativas ou independentes, visando estimar e/ou prever o valor médio da primeira em termos dos valores conhecidos ou fixados das segundas.
#
# #### Terminologia
#
# > A variável que é prevista é conhecida como variável dependente (*Y*).
#
# > A variável utilizada para prever o valor da variável dependente é conhecida como variável independente (*X*).
#
# Em nosso treinamento vamos abordar o tipo mais simples de análise de regressão que considera uma variável dependente e apenas uma variável independente onde a relação entre as variáveis se aproxima de uma linha reta.

# %% [markdown]
# ## <font color=green>4.1 Regressão linear simples</font>
# ***

# %% [markdown]
# ### Função consumo
#
# Um economista famoso do passado concluiu em um de seus estudos que os indivíduos tendem a aumentar o seu consumo conforme sua renda aumenta. Logicamente esta teoria ganhou um pouco mais de complexidade, mas vamos utilizar sua forma mais simples para entender o procedimento de análise de regressão com a seguninte formulação:
#
# # $$Y_i = \beta_1 + \beta_2X_i$$
#
# Onde
#
# - $Y_i$ é o gasto das famílias ou consumo das famílias
#
# - $X_i$ é a renda disponível
#
# - $\beta_1$ é conhecido como intercepto (no modelo teórico acima é conhecido como consumo autônomo, ou seja, o consumo quando o rendimento é zero)
#
# - $\beta_2$ é o coefiente angular (no modelo teórico é a propensão marginal a consumir)
#
# Em uma análise de regressão linear simples, o interesse está em estimar a função de regressão populacional como a apresentada acima, ou seja, estimar os valores dos parâmetros $\beta_1$ e $\beta_2$ com base nas observações de $Y$ e $X$.

# %% [markdown]
# ### Carregando o dataset

# %%
# Cria uma dicionário com duas listas de dados, com gasto e renda famíliar.
dataset = {
    'Y': [3011, 1305, 1879, 2654, 2849, 1068, 2892, 2543, 3074, 849, 2184, 2943, 1357, 2755, 2163, 3099, 1600, 353, 1778, 740, 2129, 3302, 2412, 2683, 2515, 2395, 2292, 1000, 600, 1864, 3027, 1978, 2791, 1982, 900, 1964, 1247, 3067, 700, 1500, 3110, 2644, 1378, 2601, 501, 1292, 2125, 1431, 2260, 1770],
    'X': [9714, 3728, 6062, 8845, 8378, 3338, 8507, 7947, 9915, 1632, 6825, 8918, 4100, 9184, 6180, 9997, 4500, 1069, 5925, 2466, 6083, 9712, 7780, 8383, 7185, 7483, 7640, 2100, 2000, 6012, 8902, 5345, 8210, 5662, 2700, 6546, 2900, 9894, 1500, 5000, 8885, 8813, 3446, 7881, 1164, 3401, 6641, 3329, 6648, 4800]
}

# %%
# Cria uma dataframe com os dados.
dataset = pd.DataFrame(dataset)
dataset.head()
# Out:
#       Y     X
# 0  3011  9714
# 1  1305  3728
# 2  1879  6062
# 3  2654  8845
# 4  2849  8378

# %% [markdown]
# ### Identificando a relação entre as variáveis
#
# https://seaborn.pydata.org/generated/seaborn.lmplot.html
#
# Plota a reta de regressão entre duas variáveis juntamente com a dispersão entre elas.

# %%
# Cria um gráfico de dispersão, com uma linha de tendência.
ax = sns.lmplot(x="X", y="Y", data=dataset)
ax.fig.set_size_inches(12, 6)
ax.fig.suptitle('Reta de Regressão - Gasto X Renda', fontsize=16, y=1.02)
ax.set_xlabels("Renda das Famílias", fontsize=14)
ax.set_ylabels("Gasto das Famílias", fontsize=14)
ax

# %% [markdown]
# ### Matriz de correlação

# %%
# Cria uma matriz com o calculos da correlação entre as variáveis.
dataset.corr()
# Out:
#           Y         X
# Y  1.000000  0.984835
# X  0.984835  1.000000

# %% [markdown]
# ### Função de regressão populacional
#
# A equação formulada acima é conhecida como **função de regressão populacional (FRP)** e em alguns livros é também representada da seguinte forma:
#
# # $$E(Y|X_i) = \beta_1 + \beta_2X_i$$
#
# Ela afirma que o valor esperado da distribuição de $Y$, dado $X_i$, tem uma relação funcional com $X_i$, isto é, a resposta média de $Y$ varia com $X$. O coeficientes $\beta_1$ e $\beta_2$ são conhecidos como coeficientes de regressão e também são conhecidos como intercepto e coeficiente angular, respectivamente.
#
# <img src="https://caelum-online-public.s3.amazonaws.com/1273-estatistica-parte4/01/img027.png" width=50%>
#
# O gráfico de dispersão acima deixa claro que com o aumento da renda familiar, em média, as despesas de consumo das famílias aumentam, mas não no mesmo nível. O que podemos dizer é que para um nível de renda $X_i$ as despesas médias de consumo de uma
# família agrupam-se em torno do consumo médio de todas as famílias deste nível $X_i$, isto é, em torno de sua esperança condicional $E(Y|X_i)$. Portanto, podemos expressar o desvio individual de $Y_i$ em torno de seu valor esperado da seguinte forma:
#
# # $$u_i = Y_i - E(Y|X_i)$$
#
# ou
#
# # $$Y_i = E(Y|X_i) + u_i$$
#
# onde o desvio $u_i$ é uma variável aleatória não-observável que assume valores positivos ou negativos. Esta variável é também conhecida como termo de erro estocástico.
#
# Observe que a podemos representar a FRP em sua forma estocástica da seguinte maneira:
#
# # $$Y_i = \beta_1 + \beta_2X_i + u_i$

# %% [markdown]
# ## <font color=green>4.2 O método de mínimos quadrados</font>
# ***

# %% [markdown]
# Considere a seguinte **função de regressão da população (FRP)** para duas variáveis:
#
# # $$Y_i = \beta_1 + \beta_2X_i + u_i$$
#
# Como a **FRP** não pode ser obtida de forma direta, precisamos estimá-la através da **função de regressão amostral (FRA)**.
#
# # $$Y_i = \hat{\beta}_1 + \hat{\beta}_2X_i + \hat{u}_i$$
# # $$Y_i = \hat{Y}_i + \hat{u}_i$$
#
# onde $\hat{Y}_i$ é o valor estimado de $Y_i$.
#
# A partir da equação acima podemos expressar o erro da seguinte maneira:
#
# # $$\hat{u}_i = Y_i - \hat{Y}_i$$
# # $$\hat{u}_i = Y_i - \hat{\beta}_1 - \hat{\beta}_2X_i$$
#
# A ideia é determinar **FRA** de forma que fique o mais próximo possível do valor observado de $Y$. Intuitivamente uma forma interessante de fazer isso seria determinar **FRA** de maneira que a soma dos resíduos seja a menor possível.
#
# # $$\sum\hat{u}_i = \sum{(Y_i - \hat{Y}_i)}$$
#
# Avaliando a figura abaixo se pode verificar que talvez o critério de minimizar a soma dos resíduos não seja a melhor abordagem para solucionar o problema.
#
# <img src="https://caelum-online-public.s3.amazonaws.com/1273-estatistica-parte4/01/img015.png" width=50%>
#
# O critério de minimização da soma dos resíduos assume que todos os resíduos tem o mesmo peso no somatório, o que nem sempre se comprova. Em nosso exemplo os resíduos $\hat{u}_1$ e $\hat{u}_4$ encontram-se bem mais afastados da **FRA** que $\hat{u}_2$ e $\hat{u}_3$. Isso acarreta na possibilidade de que a soma dos $\hat{u}_i$'s seja bastante pequena e até mesmo nula, mesmo que os resíduos estejam muito dispersos em relação a reta de regressão.
#
# Para evitar tal problema adotou-se o critério de minimização da soma dos quadrados dos resíduos que é conhecido como **Método de Mínimos Quadrados**.
#
# # $$\sum\hat{u}_i^2 = \sum{(Y_i - \hat{Y}_i)^2}$$
# # $$\sum\hat{u}_i^2 = \sum{(Y_i - \hat{\beta}_1 - \hat{\beta}_2X_i)^2}$$
#
# Após um procedimento de diferenciação, algumas simplificações e manipulações algébricas obtemos os **estimadores de mínimos quadrados**.
#
# # $$
# \begin{equation}
# \boxed{\hat{\beta}_2 = \frac{n\sum{X_iY_i} - \sum{X_i}\sum{Y_i}}{n\sum{X_i^2} - (\sum{X_i})^2}}
# \end{equation}
# $$
#
# # $$
# \begin{equation}
# \boxed{
# \begin{eqnarray}
# \hat{\beta}_1 &=& \frac{\sum{X_i^2}\sum{Y_i} - \sum{X_i}\sum{X_iY_i}}{n\sum{X_i^2} - (\sum{X_i})^2}\\
# &=& \bar{Y} - \hat{\beta}_2\bar{X}
# \end{eqnarray}
# }
# \end{equation}
# $$

# %% [markdown]
# ## <font color=green>4.3 Estimadores de mínimos quadrados ordinários</font>
# ***

# %% [markdown]
# ### Obter $n$

# %%
# Conta o número de elementos/registros do dataframe.
n = len(dataset)
n
# Out:
# 50

# %% [markdown]
# ### Obter $\sum{Y}$

# %%
# Soma os valores da variável Y.
SOMA_Y = dataset.Y.sum()
SOMA_Y
# Out:
# 100556

# %% [markdown]
# ### Obter $\sum{X}$

# %%
# Soma os valores da variável X.
SOMA_X = dataset.X.sum()
SOMA_X
# Out:
# 303275

# %% [markdown]
# ### Obter $\sum{X^2}$

# %% [markdown]
# Solução 1

# %%
# Cria uma nova variável (X2) no dataframe para receber o valor de X elevado ao quadrado.
dataset['X2'] = dataset.X ** 2
dataset.head()
# Out:
#       Y     X        X2
# 0  3011  9714  94361796
# 1  1305  3728  13897984
# 2  1879  6062  36747844
# 3  2654  8845  78234025
# 4  2849  8378  70190884

# %%
# Soma os valores da variável X2.
SOMA_X2 = dataset.X2.sum()
SOMA_X2
# Out:
# 2198628939

# %% [markdown]
# Solução 2

# %%
# Soma do X2, função lambda, com uma única linha de comando e sem precisar criar uma variável no dataframe.
SOMA_X2 = dataset.X.apply(lambda x: x**2).sum()
SOMA_X2
# Out:
# 2198628939

# %% [markdown]
# ### Obter $\sum{Y^2}$

# %%
# Soma o Y2, usando a função lambda.
SOMA_Y2 = dataset.Y.apply(lambda y: y**2).sum()
SOMA_Y2
# Out:
# 234954332

# %% [markdown]
# ### Obter $\sum{XY}$

# %% [markdown]
# Solução 1

# %%
# Cria uma variável XY para receber o valor da multiplicação de X por Y.
dataset['XY'] = dataset.X * dataset.Y
dataset.head()
# Out:
#       Y     X        X2        XY
# 0  3011  9714  94361796  29248854
# 1  1305  3728  13897984   4865040
# 2  1879  6062  36747844  11390498
# 3  2654  8845  78234025  23474630
# 4  2849  8378  70190884  23868922

# %%
# Soma os valores da variável XY.
SOMA_XY = dataset.XY.sum()
SOMA_XY
# Out:
# 716683794

# %% [markdown]
# Solução 2

# %%
# Soma o Y2, usando a função lambda.
SOMA_XY = dataset.apply(lambda data: data.X * data.Y, axis = 1).sum()
SOMA_XY
# Out:
# 716683794

# %% [markdown]
# Resetando dataframe

# %%
# Excluir as colunas/variáveis criadas para fazer os somatórios das variáveis.
dataset.drop(['X2', 'XY'], axis = 1, inplace = True)
dataset.head()
# Out:
#       Y     X
# 0  3011  9714
# 1  1305  3728
# 2  1879  6062
# 3  2654  8845
# 4  2849  8378

# %% [markdown]
# ### Obter $\hat{\beta}_2$
#
# # $$\hat{\beta}_2 = \frac{n\sum{X_iY_i} - \sum{X_i}\sum{Y_i}}{n\sum{X_i^2} - (\sum{X_i})^2}$$

# %%
# Calcula o coeficiente de regressão (angular), conforme fómula matemática acima.
numerador = n * SOMA_XY - SOMA_X * SOMA_Y
denominador = n * SOMA_X2 - (SOMA_X)**2
beta_2 = numerador / denominador
beta_2
# Out:
# 0.29729069099372424

# %% [markdown]
# ### Obter $\hat{\beta}_1$
#
# # $$
# \begin{eqnarray}
# \hat{\beta}_1 &=& \frac{\sum{X_i^2}\sum{Y_i} - \sum{X_i}\sum{X_iY_i}}{n\sum{X_i^2} - (\sum{X_i})^2}\\
# &=& \bar{Y} - \hat{\beta}_2\bar{X}
# \end{eqnarray}
# $$

# %%
# Calcula o coeficiente de regressão (intercepto), de forma mais simples utilizando beta_2, obtido acima.
beta_1 = dataset.Y.mean() - beta_2 * dataset.X.mean()
beta_1
# Out:
# 207.90331377756547

# %% [markdown]
# ### Obtendo a estimativa dos parâmetros com o StatsModels

# %% [markdown]
# ### Importando a biblioteca
# https://www.statsmodels.org/stable/index.html

# %%
# Importa parte da biblioteca Statsmodels.
import statsmodels.api as sm

# %%
# Cria a variável independente (X), que será utilizada para prever o valor da variável dependente (Y).
X = sm.add_constant(dataset.X) # Cria uma coluna de constantes no valor 1 e a segunda com os valores de X, dados do dataframe.
X.head()
# Out:
#    const     X
# 0    1.0  9714
# 1    1.0  3728
# 2    1.0  6062
# 3    1.0  8845
# 4    1.0  8378

# %%
# Cria a variável Y com dados do dataframe.
Y = dataset.Y
Y.head()
# Out:
# 0    3011
# 1    1305
# 2    1879
# 3    2654
# 4    2849
# Name: Y, dtype: int64

# %% [markdown]
# ### Estimando o modelo

# %%
# Calcula a regressão para obter os parâmetros, obter o R2, obter previsões, obter os resíduos e etc.
resultado_regressao = sm.OLS(Y, X, missing='drop').fit()

# %% [markdown]
# ### Visualizando os parâmetros estimados

# %%
# Exibe o valor calculada acima, do coeficiente de regressão, intercepto.
beta_1
# Out:
# 207.90331377756547

# %%
# Exibe o valor calculada acima, coeficiente de regressão, angula.
beta_2
# Out:
# 0.29729069099372424

# %%
# Exibe os parâmetros da regressão calcula acima com o método OLS(), que é a sigla para mínimos quadrado ordinários.
resultado_regressao.params
# Out:
# const    207.903314
# X          0.297291
# dtype: float64

# %%
# Seleciona o valor de const e atribui a beta_1.
beta_1 = resultado_regressao.params[0]
beta_1
# Out:
# 207.90331377756553

# %%
# Seleciona o valor de X e atribui a beta_2.
beta_2 = resultado_regressao.params[1]
beta_2
# Out:
# 0.29729069099372435

# %% [markdown]
# ### Intervalo de confiança para os parâmetros estimados

# %%
# Calcula o intervalo de confinça usando o método conf_int().
resultado_regressao.conf_int(alpha=0.05)
# Out:
#                 0           1
# const  107.116864  308.689763
# X        0.282092    0.312490

# %% [markdown]
# ### Exercício - Obtendo os betas
#
# Considere o conjunto de dados abaixo. Onde temos o número de domicílios que possuem computador (Y) e a renda total recebida por pessoas de 10 anos ou mais (X), em cada um dos estados brasileiros.
#
# Acredita-se que a posse de computadores tenha uma relação linear com a renda das famílias e para comprovar isso, podemos estimar uma regressão linear com os dados acima e avaliar os resultados obtidos.
#
# Neste problema, precisamos, inicialmente, obter as estimativas dos parâmetros de regressão.
#
# Informações extras:
#
# > O valor da renda está dividido por 1.000.000, isto é, se um estado tem uma renda total de 4,20 reais, significa que ele tem uma renda total de R$ 4.200.000.
#
# > Utilize o ferramental do statsmodels para obter os parâmetros.
#
# > Segue o dataset em formato de dicionário Python para facilitar a solução do problema:
# * Y é o número de domicílios que possuem computador.
# * X é a renda total recebida por pessoas de 10 anos ou mais, em cada um dos estados brasileiros.

# %%
dataset_E = {
    'Y': [670, 220, 1202, 188, 1869, 248, 477, 1294, 816, 2671, 1403, 1586, 3468, 973, 701, 5310, 10950, 2008, 9574, 28863, 6466, 4274, 6432, 1326, 1423, 3211, 2140],
    'X': [1.59, 0.56, 2.68, 0.47, 5.2, 0.58, 1.32, 3.88, 2.11, 5.53, 2.6, 2.94, 6.62, 1.91, 1.48, 10.64, 22.39, 4.2, 21.9, 59.66, 14.22, 9.57, 14.67, 3.28, 3.49, 6.94, 6.25]
}

# %%
# Cria uma dataframe com os dados.
dataset_E = pd.DataFrame(dataset_E)
dataset_E.head()
# Out:
#       Y     X
# 0   670  1.59
# 1   220  0.56
# 2  1202  2.68
# 3   188  0.47
# 4  1869  5.20

# %%
# Cria a variável independente (X), que será utilizada para prever o valor da variável dependente (Y).
X = sm.add_constant(dataset_E.X) # Cria uma coluna de constantes no valor 1, e a segunda com os valores de X, dados do dataframe.
X.head()
# Out:
#    const     X
# 0    1.0  1.59
# 1    1.0  0.56
# 2    1.0  2.68
# 3    1.0  0.47
# 4    1.0  5.20

# %%
# Cria a variável Y com dados do dataframe.
Y = dataset_E.Y
Y.head()
# Out:
# 0     670
# 1     220
# 2    1202
# 3     188
# 4    1869
# Name: Y, dtype: int64

# %%
# Calcula a regressão para obter os parâmetros, obter o R2, obter previsões, obter os resíduos e etc.
resultado_regressao_E = sm.OLS(Y, X, missing='drop').fit()

# %%
# Exibe os parâmetros da regressão calcula acima com o método OLS(), que é a sigla para mínimos quadrado ordinários.
resultado_regressao_E.params
# Out:
# const   -168.321156
# X        481.390397
# dtype: float64

# %%
# Resolução apresentada.
dataset_E = pd.DataFrame(dataset_E)

Y = dataset_E.Y
X = sm.add_constant(dataset_E.X)

resultado_regressao_E = sm.OLS(Y, X, missing='drop').fit()
resultado_regressao_E.params
# Out:
# const   -168.321156
# X        481.390397
# dtype: float64

# %% [markdown]
# ## <font color=green>4.4 Obtendo previsões</font>
# ***

# %% [markdown]
# ### $\hat{Y}_i = \beta_1 + \beta_2$
#
#   $\hat{Y}_i = 207,9033 + 0,2973X_i$

# %% [markdown]
# ### Previsões dentro da amostra

# %%
# Calcula a previsão, considerando valores da amostra.
dataset['Y_previsto'] = beta_1 + beta_2 * dataset.X
dataset.head()
# Out:
#       Y     X   Y_previsto
# 0  3011  9714  3095.785086
# 1  1305  3728  1316.203010
# 2  1879  6062  2010.079483
# 3  2654  8845  2837.439476
# 4  2849  8378  2698.604723

# %% [markdown]
# ### Utilizando o statsmodels

# %%
# Calcula a previsão utilizando o método predict().
dataset['Y_previsto_statsmodels'] = resultado_regressao.predict()
dataset.head()
# Out:
#       Y     X   Y_previsto  Y_previsto_statsmodels
# 0  3011  9714  3095.785086             3095.785086
# 1  1305  3728  1316.203010             1316.203010
# 2  1879  6062  2010.079483             2010.079483
# 3  2654  8845  2837.439476             2837.439476
# 4  2849  8378  2698.604723             2698.604723

# %%
# Exclui a coluna de previsão criada pelo método predict().
dataset.drop(['Y_previsto_statsmodels'], axis = 1, inplace = True)
dataset.head()
# Out:
#       Y     X   Y_previsto
# 0  3011  9714  3095.785086
# 1  1305  3728  1316.203010
# 2  1879  6062  2010.079483
# 3  2654  8845  2837.439476
# 4  2849  8378  2698.604723

# %% [markdown]
# ### Estimando o 'Gasto das Famílias' fora da amostra

# %%
# Calcula a previsão, considerando valores fora da amostra também.
def prever(x):
  return beta_1 + beta_2 * x

# %%
# Usando a função prever(), criada acima, é possível passar como parâmetro um valor da renda para prever o gasto.
prever(7510)
# Out:
# 2440.556403140435

# %% [markdown]
# ### Estimando o 'Gasto das Famílias' fora da amostra via StatsModels

# %%
# Calcula a previsão, considerando valores fora da amostra também.
# Passando como parâmetro a const e o valor do renda para prever o gasto.
resultado_regressao.predict([1, 7510])[0]
# Out:
# 2440.556403140435

# %% [markdown]
# ### Exercício - Fazendo previsões com nosso modelo
#
# Considerando os dados do problema anterior, onde se acredita que a posse de computadores tenha uma relação linear com a renda das famílias, após estimarmos o modelo (problema anterior), suponha que seja criado um estado e que este apresente uma renda total de R$ 2.345.678.
#
# Informações extras:
#
# > O valor da renda está dividido por 1.000.000, isto é, se um estado tem uma renda total de 4,20 reais, significa que ele tem uma renda total de R$ 4.200.000.
#
# > Utilize o ferramental do statsmodels para solucionar o problema.
#
# > Segue o dataset em formato de dicionário Python para facilitar a solução do problema:
# * Y é o número de domicílios que possuem computador.
# * X é a renda total recebida por pessoas de 10 anos ou mais, em cada um dos estados brasileiros.

# %%
dataset_E = {
    'Y': [670, 220, 1202, 188, 1869, 248, 477, 1294, 816, 2671, 1403, 1586, 3468, 973, 701, 5310, 10950, 2008, 9574, 28863, 6466, 4274, 6432, 1326, 1423, 3211, 2140],
    'X': [1.59, 0.56, 2.68, 0.47, 5.2, 0.58, 1.32, 3.88, 2.11, 5.53, 2.6, 2.94, 6.62, 1.91, 1.48, 10.64, 22.39, 4.2, 21.9, 59.66, 14.22, 9.57, 14.67, 3.28, 3.49, 6.94, 6.25]
}

# %%
# Cria uma dataframe com os dados.
dataset_E = pd.DataFrame(dataset_E)
dataset_E.head()
# Out:
#       Y     X
# 0   670  1.59
# 1   220  0.56
# 2  1202  2.68
# 3   188  0.47
# 4  1869  5.20

# %%
# Cria as variáveis X e Y, com o dados do dataframe.
X = sm.add_constant(dataset_E.X)
Y = dataset_E.Y

# %%
# Calcula a regressão para obter os parâmetros, obter o R2, obter previsões, obter os resíduos e etc.
resultado_regressao_E = sm.OLS(Y, X, missing='drop').fit()

# %%
# Calcula a previsão utilizando o método predict().
dataset_E['Y_previsto_statsmodels'] = resultado_regressao_E.predict()
dataset_E.head()
# Out:
#       Y     X  Y_previsto_statsmodels
# 0   670  1.59              597.089575
# 1   220  0.56              101.257466
# 2  1202  2.68             1121.805108
# 3   188  0.47               57.932331
# 4  1869  5.20             2334.908908

# %%
# Calcula a previsão, considerando valores fora da amostra também.
# Passando como parâmetro a const e o valor do renda para prever o gasto.
resultado_regressao_E.predict([1, 2.345678])[0]
# Out:
# 960.8657076138518

# %%
# Resolução apresentada.
resultado_regressao_E.predict([1, 2.345678])[0]
# Out:
# 960.8657076138518

# %% [markdown]
# ## <font color=green>4.5 Resíduos</font>
# ***

# %% [markdown]
# Como vimos anteriormente, o resíduo da i-ésima observação é a diferença entre o valor observado de nossa variável dependente ($Y_i$) e o valor estimado da variável dependente ($\hat{Y}_i$).

# %% [markdown]
# $$\hat{u}_i = Y_i - \hat{Y}_i$$

# %% [markdown]
# Em outras palavras, $\hat{u}_i$ é o erro obtido ao se utilizar a equação de regressão estimada para prever o valor da variável dependente.

# %% [markdown]
# Resolução 1

# %%
# Calcula o residuo, conforme fórmula matemática.
dataset['u'] = dataset.Y - dataset.Y_previsto
dataset.head()
# Out:
#       Y     X   Y_previsto           u
# 0  3011  9714  3095.785086  -84.785086
# 1  1305  3728  1316.203010  -11.203010
# 2  1879  6062  2010.079483 -131.079483
# 3  2654  8845  2837.439476 -183.439476
# 4  2849  8378  2698.604723  150.395277

# %% [markdown]
# Resolução 2

# %%
# Calcula o residuos, utilizando método resid, da biblioteca statsmodels.
dataset['Residuos'] = resultado_regressao.resid
dataset.head()
# Out:
#       Y     X   Y_previsto           u    Residuos
# 0  3011  9714  3095.785086  -84.785086  -84.785086
# 1  1305  3728  1316.203010  -11.203010  -11.203010
# 2  1879  6062  2010.079483 -131.079483 -131.079483
# 3  2654  8845  2837.439476 -183.439476 -183.439476
# 4  2849  8378  2698.604723  150.395277  150.395277

# %%
# Exclui a coluna u criada anteriormente.
dataset.drop(['u'], axis = 1, inplace = True)
dataset.head()
# Out:
#       Y     X   Y_previsto    Residuos
# 0  3011  9714  3095.785086  -84.785086
# 1  1305  3728  1316.203010  -11.203010
# 2  1879  6062  2010.079483 -131.079483
# 3  2654  8845  2837.439476 -183.439476
# 4  2849  8378  2698.604723  150.395277

# %% [markdown]
# ## <font color=green>4.6 Suposições sobre o termo de erro $u$</font>
# ***
#
# ### 1. O termo de erro $u$ é uma variável aleatória com média igual a zero: $E(u) = 0$
# ### 2. A variância de $u$ é a mesma para todos os valores de $X$
# ### 3. O valores de $u$ são independentes
# ### 4. O termo de erro $u$ é uma variável aleatória normalmente distribuída.

# %%
# Calcula a média da variável residuos, que mostra que a média dessa variável é pequena (E(u)=0), conforme a primeira suposição acima.
dataset.Residuos.mean()
# Out:
# -5.525180313270539e-13

# %% [markdown]
# ### Plotando os resíduos do modelo
#
# https://seaborn.pydata.org/generated/seaborn.scatterplot.html

# %%
# Cria um gráfico de dispersão simples, com duas variáveis.
ax = sns.scatterplot(x=dataset.X, y=dataset.Residuos)
ax.figure.set_size_inches(12, 6)
ax.set_title('Resíduos vs Variável Independente', fontsize=18)
ax.set_xlabel('X', fontsize=14)
ax.set_ylabel('Resíduos', fontsize=14)
ax
# Out:
# <Axes: title={'center': 'Resíduos vs Variável Independente'}, xlabel='X', ylabel='Resíduos'>

# %%
# Cria um gráfico de dispersão múltipla, com as duas variáveis.
ax = sns.scatterplot(x=dataset.Y_previsto, y=dataset.Residuos)
ax.figure.set_size_inches(12, 6)
ax.set_title('Resíduos vs Y_Previsto', fontsize=18)
ax.set_xlabel('Y_Previsto', fontsize=14)
ax.set_ylabel('Resíduos', fontsize=14)
ax
# Out:
# <Axes: title={'center': 'Resíduos vs Y_Previsto'}, xlabel='Y_Previsto', ylabel='Resíduos'>

# %% [markdown]
# ### Hipótese de variância constante

# %% [markdown]
# <img src="https://caelum-online-public.s3.amazonaws.com/1273-estatistica-parte4/01/img028.jpg" width=80%>
#
# Fonte: Econometria Básica - 5ª edição - Gujarati e Porter

# %%
# Cria um gráfico de dispersão múltipla, com as duas variáveis.
ax = sns.scatterplot(x=dataset.Y_previsto, y=dataset.Residuos**2)
ax.figure.set_size_inches(12, 6)
ax.set_title('Resíduos² vs Y_Previsto', fontsize=18)
ax.set_xlabel('Y_Previsto', fontsize=14)
ax.set_ylabel('Resíduos²', fontsize=14)
ax
# Out:
# <Axes: title={'center': 'Resíduos² vs Y_Previsto'}, xlabel='Y_Previsto', ylabel='Resíduos²'>

# %% [markdown]
# ## <font color=green>4.7 O coeficiente de determinação $R^2$</font>
# ***

# %% [markdown]
# O **coeficiente de determinação R²** é uma medida resumida que diz quanto a linha de regressão amostral se ajusta aos dados. Pode ser obtido a partir da seguinte fórmula:
#
# # $$R^2 = \frac{\big[\sum{(Y_i - \bar{Y})(\hat{Y}_i - \bar{Y})}\big]^2}{\sum{(Y_i - \bar{Y}})^2 \sum{(\hat{Y}_i - \bar{Y}})^2}$$
#
# Sabemos que o i-ésimo resíduo representa o erro de usarmos $\hat{Y}_i$ para estimar $Y_i$. A soma dos quadrados desses resíduos é o valor que é minimizado pelo método dos mínimos quadrados. Esse valor pode ser representado da seguinte forma:
#
# # $$SQE = \sum{(Y_i - \hat{Y}_i)^2}$$
#
# O valor da SQE é uma medida do erro de se usar a equação de regressão estimada para estimar os valores da variável dependente na amostra.
#
# Outro componente que podemos medir é a soma dos quadrados total (SQT) que representa a medida do erro envolvido no uso da média ($\bar{Y}$) para fazer as estimativas. A SQT pode ser representada da forma abaixo:
#
# # $$SQT = \sum{(Y_i - \bar{Y})^2}$$
#
# Para quantificar o quanto os valores estimados ($\hat{Y}_i$) se afastam da média ($\bar{Y}$) podemos obter mais uma soma de quadrados. Essa soma é chamada de soma dos quadrados da regressão (SQR) e é representada pela seguinte fórmula:
#
# # $$SQR = \sum{(\hat{Y}_i - \bar{Y})^2}$$

# %% [markdown]
# ### Soma do quadrados dos erros (SQE)

# %%
# Mostras os primeiros resgistros do dataframe.
dataset.head()
# Out:
#       Y     X   Y_previsto    Residuos
# 0  3011  9714  3095.785086  -84.785086
# 1  1305  3728  1316.203010  -11.203010
# 2  1879  6062  2010.079483 -131.079483
# 3  2654  8845  2837.439476 -183.439476
# 4  2849  8378  2698.604723  150.395277

# %% [markdown]
# Solução 1

# %%
# Calcula a soma dos quadrados dos resíduos, conforme fórmula matemática.
SQE = dataset.Residuos.apply(lambda u: u**2).sum()
SQE
# Out:
# 984986.0375191914

# %% [markdown]
# Solução 2

# %%
# Calcula a soma dos quadrados dos resíduos, utilizando o método ssr (sum of squared residuals) da biblioteca statsmodels.
resultado_regressao.ssr
# Out:
# 984986.0375191915

# %% [markdown]
# ### Soma do quadrados total (SQT)

# %% [markdown]
# Solução 1

# %%
# Calcula a soma dos quadrados total, conforme fórmula matemática.
SQT = dataset.Y.apply(lambda y: (y - dataset.Y.mean())**2).sum()
SQT
# Out:
# 32724149.279999997

# %% [markdown]
# ### Soma do quadrados da regressão (SQR)

# %% [markdown]
# Solução 1

# %%
# Calcula a soma dos quadrados da regressão, conforme fórmula matemática.
SQR = dataset.Y_previsto.apply(lambda y: (y - dataset.Y.mean())**2).sum()
SQR
# Out:
# 31739163.24248083

# %% [markdown]
# Solução 2

# %%
# Calcula a soma dos quadrados da regressão, utilizando o método ess (explained sum of squares) do statsmodels.
resultado_regressao.ess
# Out:
# 31739163.242480807

# %% [markdown]
# ### Soma do quadrados total (SQT)

# %% [markdown]
# Solução 2

# %%
# Calcula a soma dos quadrados total, conforme fórmula matemática.
SQT = SQR + SQE
SQT
# Out:
# 32724149.28000002

# %% [markdown]
# ### Relação entre as somas de quadrados
#
# # $$SQT = SQR + SQE$$
#
# Onde,
#
#
# ### $SQE = \sum{(Y_i - \hat{Y}_i)^2}$
#
# ### $SQT = \sum{(Y_i - \bar{Y})^2}$
#
# ### $SQR = \sum{(\hat{Y}_i - \bar{Y})^2}$
#
#
# <img src="https://caelum-online-public.s3.amazonaws.com/1273-estatistica-parte4/01/img029.png" width=50%>

# %% [markdown]
# ### Coeficiente de determinação (R²)
#
# A regressão estimada teria um ajuste perfeito se todos os valores da variável dependente ($Y_i$) estiverem sobre a reta de regressão estimada. Quando isso ocorre temos $Y_i - \hat{Y}_i = 0$ para todas as observações, o que resulta em uma $SQE = 0$. Como $SQT=SQR+SQE$, é possível deduzir que para termos um ajuste perfeito $SQT$ deve ser igual a $SQR$ e a razão entre estas medidas ($\frac{SQR}{SQT}$) deve ser igual a 1.
#
# Quando o ajuste não é tão perfeito nota-se que a $SQE$ apresenta valores maiores o que faz a razão $\frac{SQR}{SQT}$ diminuir, e em uma situação de total imperfeição do ajuste teríamos uma $SQR=0$ e $SQE=SQT$ levando a $\frac{SQR}{SQT}=0$.
#
# A razão $\frac{SQR}{SQT}$, que assume valores entre 0 e 1, é utilizada como medida de eficiência do ajuste da equação de regressão estimada. Essa medida é conhecida como coeficiente de determinação (R²).
#
# # $$R^2 = \frac{SQR}{SQT}$$
#
# ## <font color='red'>Observação</font>
# > Somente com a utilização do R² não é possível tirar conclusões sobre a relação entre $Y$ e $X$ ser ou não ser estatisticamente
# significativa. Este tipo de afirmação deve basear-se em considerações que envolvem o tamanho da amostra e as propriedades da distribuição amostral dos estimadores mínimos quadrados.

# %% [markdown]
# Solução 1

# %%
# Calcula o R², coeficiente de determinação, conforme fómula matemática.
R2 = SQR / SQT
R2
# Out:
# 0.9699003317369297

# %% [markdown]
# Solução 2

# %%
# Calcula o R², coeficiente de determinação, utilizando o método rsquared do statsmodels.
resultado_regressao.rsquared
# Out:
# 0.9699003317369297

# %% [markdown]
# ### Exercício - Obtendo o R² de nosso modelo
#
# Considerando os dados do problema proposto em exercícios anteriores, onde se acredita que a posse de computadores tenha uma relação linear com a renda das famílias.
#
# Informações extras:
#
# > O valor da renda está dividido por 1.000.000, isto é, se um estado tem uma renda total de 4,20 reais, significa que ele tem uma renda total de R$ 4.200.000.
#
# > Utilize o ferramental do statsmodels para solucionar o problema.
#
# > Segue o dataset em formato de dicionário Python para facilitar a solução do problema:
# * Y é o número de domicílios que possuem computador.
# * X é a renda total recebida por pessoas de 10 anos ou mais, em cada um dos estados brasileiros.

# %%
dataset_E = {
    'Y': [670, 220, 1202, 188, 1869, 248, 477, 1294, 816, 2671, 1403, 1586, 3468, 973, 701, 5310, 10950, 2008, 9574, 28863, 6466, 4274, 6432, 1326, 1423, 3211, 2140],
    'X': [1.59, 0.56, 2.68, 0.47, 5.2, 0.58, 1.32, 3.88, 2.11, 5.53, 2.6, 2.94, 6.62, 1.91, 1.48, 10.64, 22.39, 4.2, 21.9, 59.66, 14.22, 9.57, 14.67, 3.28, 3.49, 6.94, 6.25]
}

# %%
# Cria uma dataframe com os dados.
dataset_E = pd.DataFrame(dataset_E)
dataset_E.head()
# Out:
#       Y     X
# 0   670  1.59
# 1   220  0.56
# 2  1202  2.68
# 3   188  0.47
# 4  1869  5.20

# %%
# Cria as variáveis X e Y, com o dados do dataframe.
X = sm.add_constant(dataset_E.X)
Y = dataset_E.Y

# %%
# Calcula a regressão para obter os parâmetros, obter o R2, obter previsões, obter os resíduos e etc.
resultado_regressao_E = sm.OLS(Y, X, missing='drop').fit()

# %%
# Calcula o R², coeficiente de determinação, utilizando o método rsquared do statsmodels.
resultado_regressao_E.rsquared
# Out:
# 0.9967917066613234

# %%
# Resolução apresentada.
Y = dataset.Y
X = sm.add_constant(dataset.X)

resultado_regressao = sm.OLS(Y, X, missing='drop').fit()
resultado_regressao.rsquared
# Out:
# 0.9699003317369297

# %% [markdown]
# ## <font color=green>4.8 Testes aplicados a modelos de regressão</font>
# ***

# %% [markdown]
# Como vimos, em uma regressão linear simples, a média da variável dependente ($Y$) é uma função linear da variável independente ($X$):
#
# # $$Y_i = \beta_1 + \beta_2X_i$$
#
# Se o valor de $\beta_2$ for zero podemos verificar que o valor médio de $Y$ não depende do valor de $X$ e, portanto, concluímos que $X$ e $Y$ não estão linearmente relacionados. De forma alternativa, se o valor de $\beta_2$ não for igual a zero, concluímos que as duas variáveis estão relacionadas.
#
# Para testar se a relação de regressão é significativa, é preciso realizar um **teste de hipóteses** para determinar se o valor de $\beta_2$ é zero. Antes de realizar este tipo de teste precisamos obter uma estimativa para $\sigma^2$ (variância do erro).

# %% [markdown]
# ### Output do modelo de regressão estimado

# %%
# Mostra um resumo do modelo de regressão.
print(resultado_regressao.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.970
# Model:                            OLS   Adj. R-squared:                  0.969
# Method:                 Least Squares   F-statistic:                     1547.
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           3.56e-38
# Time:                        23:55:44   Log-Likelihood:                -318.16
# No. Observations:                  50   AIC:                             640.3
# Df Residuals:                      48   BIC:                             644.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        207.9033     50.127      4.148      0.000     107.117     308.690
# ...

# %% [markdown]
# ### Erro quadrático médio - estimativa de $\sigma^2$
#
# Lembre-se que a **soma dos quadrados do erros (SQE)** é uma medida numérica da variabilidade dos dados observados em torno da reta de regressão estimada. Todas as somas de quadrados, estudadas anteriormente, estão associadas a um determinado número de graus de liberdade. No caso da SQE, como devem ser estimados dois parâmetros, temos $n-2$ graus de liberdade.
#
# O **erro quadrático médio**, representado pela equação abaixo, pode ser obtido dividindo-se a SQE por $n-2$ graus de liberdade.
#
# # $$EQM = \frac{SQE}{n-2}$$

# %% [markdown]
# Solução 1

# %%
# Mostra o valor da soma dos quadrados dos resíduos.
SQE
# Out:
# 984986.0375191914

# %%
# Mostra o valor n, observações/registros.
n
# Out:
# 50

# %%
# Calcula o erro quadrático médio, conforme fórmula matemática.
EQM = SQE / (n - 2)
EQM
# Out:
# 20520.542448316486

# %% [markdown]
# Solução 2

# %%
# Calcula o erro quadrático médio, utilizando o método resid da biblioteca statsmodels.
EQM = resultado_regressao.mse_resid
EQM
# Out:
# 20520.54244831649

# %% [markdown]
# Solução 3

# %%
# Calcula o erro quadrático médio, utilizando o método ssr e resid da biblioteca statsmodels.
EQM = resultado_regressao.ssr / resultado_regressao.df_resid
EQM
# Out:
# 20520.54244831649

# %% [markdown]
# # Teste de hipótese para nulidade do coeficiente angular

# %% [markdown]
# Considere o seguinte modelo de regressão linear simples:
#
# # $$Y_i = \beta_1 + \beta_2X_i + u_i$$
#
# Se as variáveis $Y$ e $X$ são linearmente relacionadas, espera-se que $\beta_2$ seja diferente de zero. Para testar esta hipótese formulamos um teste de hipótese com a seguinte especificação de hipóteses nula e alternativa:
#
# ## $H_0: \beta_2 = 0$
# ## $H_1: \beta_2 \neq 0$
#
# Caso $H_0$ seja rejeitada, concluiremos que existe uma relação linear estatisticamente significativa entre as duas variáveis.
#
# Considere agora que $b_1$ e $b_2$ são nossos estimadores de mínimos quadrados. Considere que a distribuição amostral de $b_2$ segue uma normal e também as seguintes propriedades:
#
# # $$E(b_2) = \beta_2$$
# # $$\sigma_{b_2} = \frac{\sigma}{\sqrt{\sum{(X_i - \bar{X})^2}}}$$
#
# Como não conhecemos o valor de $\sigma$, utilizamos $s$ como estimativa:
#
# # $$s_{b_2} = \frac{s}{\sqrt{\sum{(X_i - \bar{X})^2}}}$$
#
# Note que o valor esperado de $b_2$ é $\beta_2$, logo, $b_2$ é um estimador não viesado de $\beta_2$. Abaixo temos a estatística de teste (t) que segue uma distribuição t de Student com $n-2$ graus de liberdade.
#
# # $$t = \frac{b_2 - \beta_2}{s_{b_2}}$$

# %% [markdown]
# ## Teste T

# %% [markdown]
# Solução 1

# %% [markdown]
# ### Calculando $s$

# %%
# Calcula o desvio padrão da amostra, extrair a raiz quadrada do EQM (erro quadrático médio),
s = np.sqrt(resultado_regressao.mse_resid)
s
# Out:
# 143.24993001155877

# %% [markdown]
# ### Calculando $\sum{(X_i - \bar{X})^2}$

# %%
# Calcula a somatória do desvio, conforme fórmula matemática.
SOMA_DESVIO2 = dataset.X.apply(lambda x: (x - dataset.X.mean())**2).sum()
SOMA_DESVIO2
# Out:
# 359114426.5

# %% [markdown]
# ### Calculando $s_{b_2}$

# %%
# Calacula o beta_2 do desvio.
s_beta_2 = s / np.sqrt(SOMA_DESVIO2)
s_beta_2
# Out:
# 0.00755923753376846

# %% [markdown]
# ### Determinando as áreas de aceitação e rejeição de $H_0$

# %%
# Importa parte da biblioteca Scipy.
from scipy.stats import t as t_student

# %% [markdown]
# ![Região de Aceitação](https://caelum-online-public.s3.amazonaws.com/1273-estatistica-parte4/01/img031.png)

# %% [markdown]
# ### Níveis de confiança e significância

# %%
# Define níveis de confiança e significância.
confianca = 0.95
significancia = 1 - confianca

# %%
# Obtem o grau de liberdade (n - 2) direto da regressão.
graus_de_liberdade = resultado_regressao.df_resid
graus_de_liberdade
# Out:
# 48.0

# %% [markdown]
# ### Obtendo $t_{\alpha/2}$

# %%
# Calcula a probabilidade, que é a área de aceitação, que vai do t_alpha_2 até o final.
probabilidade = (0.5 + (confianca / 2))
probabilidade
# Out:
# 0.975

# %%
# Calcula o t_alpha_2, que é o valor divide a área de aceitação e rejeição.
t_alpha_2 = t_student.ppf(probabilidade, graus_de_liberdade)
t_alpha_2
# Out:
# 2.0106347546964454

# %% [markdown]
# ![Região de Aceitação](https://caelum-online-public.s3.amazonaws.com/1273-estatistica-parte4/01/img032.png)

# %% [markdown]
# ### Obtendo $t = \frac{b_2 - \beta_2}{s_{b_2}}$

# %%
# Calcula t, estatística de teste, conforme fórmula matemática.
t = (beta_2 - 0) / s_beta_2
t
# Out:
# 39.328131926755034

# %% [markdown]
# Solução 2

# %%
# Calcula t, estatística de teste, utilizando o método tvalues.
resultado_regressao.tvalues[1]
# Out:
# 39.32813192675501

# %% [markdown]
# ![Região de Aceitação](https://caelum-online-public.s3.amazonaws.com/1273-estatistica-parte4/01/img033.png)

# %% [markdown]
# ### Etapas e regras de decisão do teste t de significância dos parâmetros

# %% [markdown]
# <img src="https://caelum-online-public.s3.amazonaws.com/1273-estatistica-parte4/01/img030.png" width=90%>

# %% [markdown]
# ### <font color='red'>Critério do valor crítico</font>
#
# > ### Teste Bicaudal
# > ### Rejeitar $H_0$ se $t \leq -t_{\alpha / 2}$ ou se $t \geq t_{\alpha / 2}$

# %%
# Verifica se a hipótese é verdadeira.
t <= -t_alpha_2
# Out:
# False

# %%
# Verifica se a hipótese é verdadeira.
t >= t_alpha_2
# Out:
# True

# %% [markdown]
# ### <font color='red'>Critério do $p-valor$</font>
#
# > ### Teste Bicaudal
# > ### Rejeitar $H_0$ se o valor $p\leq\alpha$

# %% [markdown]
# Solução 1

# %%
# Calcula o p-valor.
p_valor = 2 * (t_student.sf(t, graus_de_liberdade))
p_valor
# Out:
# 3.555543228585887e-38

# %% [markdown]
# Solução 2

# %%
# Calcula o p-valor, utilizando o método pvalues.
p_valor = resultado_regressao.pvalues[1]
p_valor
# Out:
# 3.5555432285859883e-38

# %%
# Verifica se a hipótese é verdadeira.
p_valor <= significancia
# Out:
# True

# %% [markdown]
# ### <font color='green'>Conclusão
#
# Rejeitamos $H_0$ e concluímos que existe uma relação significativa entre as duas variáveis.</font>

# %%
# Mostra um resumo do modelo de regressão.
print(resultado_regressao.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.970
# Model:                            OLS   Adj. R-squared:                  0.969
# Method:                 Least Squares   F-statistic:                     1547.
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           3.56e-38
# Time:                        23:55:45   Log-Likelihood:                -318.16
# No. Observations:                  50   AIC:                             640.3
# Df Residuals:                      48   BIC:                             644.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        207.9033     50.127      4.148      0.000     107.117     308.690
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Teste F

# %% [markdown]
# O teste F também é uma ferramenta para testar a significância na regressão. Baseado na distribuição F de probabilidade, o teste F é utilizado para verificar a significância global na regressão, isto é, em uma regressão múltipla, onde existe mais de uma variável independente, o teste F verifica a nulidade de todos os parâmetros do modelo conjuntamente.
#
# Em nosso caso (regressão linear simples) ele fornece a mesma conclusão obtida com o teste t.
#
# ## **Hipóteses:**
#
# $H_0: \beta_2 = 0$
#
# $H_1: \beta_2 \neq 0$
#
#
# ## **Estatística de teste:**
#
# ## $$F = \frac{\frac{SQR}{k}}{\frac{SQE}{n-k-1}}$$
#
#
# Onde,
#
# $SQR$ - soma dos quadrados da regressão
#
# $SQE$ - soma dos quadrados dos erros
#
# $k$ - total de variáveis independentes ($X$)
#
# **Regras de rejeição de $H_0$:**
#
# **Critério do valor crítico** $\rightarrow$ Rejeitar se $F \geq F_{\alpha}$
#
#
# Onde,
#
# $F_{\alpha}$ - baseia-se na distribuição F com $k$ graus de liberdade no numerador e $n-k-1$ no denominador.
#
# **Critério do p-valor** $\rightarrow$ Rejeitar se $p-valor \leq \alpha$

# %% [markdown]
# ### Calculando a estatística de teste ($F$)

# %% [markdown]
# Solução 1

# %%
# Calcula a soma dos quadrados da regressão SQR, utilizando a biblioteca statsmodels.
resultado_regressao.mse_model
# Out:
# 31739163.242480807

# %%
# Calcula o erro quadrático médio EQM, utilizando o método resid da biblioteca statsmodels.
resultado_regressao.mse_resid
# Out:
# 20520.54244831649

# %%
# Calcula a estatística de teste de F.
F = resultado_regressao.mse_model / resultado_regressao.mse_resid
F
# Out:
# 1546.7019608482472

# %% [markdown]
# Solução 2

# %%
# Calcula a estatística de teste de F.
resultado_regressao.fvalue
# Out:
# 1546.7019608482472

# %% [markdown]
# ### Obtendo o p-valor

# %% [markdown]
# Solução 1

# %%
# Calcula o p-valor.
resultado_regressao.f_pvalue
# Out:
# 3.5555432285860227e-38

# %% [markdown]
# Solução 2

# %%
# Importa parte da biblioteca Scipy.
from scipy.stats import f

# %%
# Calcula o p-valor, utilizando a função f.sf(), informando como parâmetros: estatística de teste f, k e grau de libertada (n - 2).
p_valor = f.sf(F, 1, 48)
p_valor
# Out:
# 3.5555432285860227e-38

# %%
# Verifica se a hipótese é verdadeira.
p_valor <= 0.05
# Out:
# True

# %% [markdown]
# # <font color=green>5 EXTRAS</font>
# ***

# %% [markdown]
# ## <font color=green>5.1 Outros testes</font>
# ***

# %%
# Mostra um resumo do modelo de regressão.
print(resultado_regressao.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       0.970
# Model:                            OLS   Adj. R-squared:                  0.969
# Method:                 Least Squares   F-statistic:                     1547.
# Date:                Tue, 28 Nov 2023   Prob (F-statistic):           3.56e-38
# Time:                        23:55:45   Log-Likelihood:                -318.16
# No. Observations:                  50   AIC:                             640.3
# Df Residuals:                      48   BIC:                             644.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        207.9033     50.127      4.148      0.000     107.117     308.690
# ...

# %% [markdown]
# ### Normalidade dos resíduos - Omnibus
#
# > ### $H_0:$ Os dados se distribuem como uma normal
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.normaltest.html

# %%
from scipy.stats import normaltest

# %%
# Calcula o valor estatístico do teste normalidade e o p-valor.
stat_test, p_valor = normaltest(dataset.Residuos)
print(stat_test)
print(p_valor)
# Out:
# 22.8329680279357
# 1.1012451024593462e-05

# %%
# Verifica se a hipótese é verdadeira.
p_valor <= 0.05
# Out:
# True

# %% [markdown]
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.probplot.html

# %%
# Importa parte da biblioteca Scipy.
from scipy.stats import probplot

# %%
# Importa biblioteca.
import matplotlib.pyplot as plt

# %%
# Cria um gráfico que faz uma comparação de distribuições de probabilidade, com a variável resíduos.
(_, (_, _, _)) = probplot(dataset.Residuos, plot = plt)

# %%
# Cria um gráfico de barras com a variável altura.
dados.Altura.hist(bins=50)
# Out:
# <Axes: >

# %%
# Cria um gráfico que faz uma comparação de distribuições de probabilidade, com a variável altura.
(_, (_, _, _)) = probplot(dados.Altura, plot = plt)

# %% [markdown]
# ### Verificando a simetria
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.skew.html

# %%
# Importa parte da biblioteca Scipy.
from scipy.stats import skew

# %%
# Calcula o valor de skew, coeficiente de assimetria, que é a semetria da curva.
S = skew(dataset.Residuos)
S
# Out:
# 0.07306920116444166

# %% [markdown]
# ### Verificando a curtose
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.kurtosis.html

# %%
# Importa parte da biblioteca Scipy.
from scipy.stats import kurtosis

# %%
# Calcula o valor de kurtosis, coeficiente de curtose, que é o achatamento da curva.
C = 3 + kurtosis(dataset.Residuos)
C
# Out:
# 1.6369621580686435

# %% [markdown]
# ### Normalidade dos resíduos - Jarque-Bera (statsmodels)
#
# > ### $H_0:$ Os dados se distribuem como uma normal
#
# > ### Estatística de teste
# > ### $$JB = \frac{n}{6}(S^2 + \frac{1}{4}(C - 3)^2)$$
# > #### Onde,
# > #### $n$ - número de observações
# > #### $S$ - Coeficiente de assimetria
# > #### $C$ - Coeficiente de curtose

# %%
# Calcula a estatística de teste de Jarque-Bera, conforme fómula matemática.
JB = (n / 6.) * (S ** 2 + (1 / 4.) * (C - 3) ** 2)
JB
# Out:
# 3.915059564941934

# %%
# Importa parte da biblioteca Scipy.
from scipy.stats import chi2

# %%
# Calcula o p-valor, tendo como parâmetros o valor estatístico de Jarque-Bera e os graus de liberdade.
p_valor = chi2.sf(JB, 2)
p_valor
# Out:
# 0.14120680197285554

# %%
# Verifica se a hipótese é verdadeira.
p_valor <= 0.05
# Out:
# False

# %% [markdown]
# ### Normalidade dos resíduos - Jarque-Bera (Correção)
#
# > ### $H_0:$ Os dados se distribuem como uma normal
#
# > ### Estatística de teste
# > ### $$JB = \frac{n-k}{6}(S^2 + \frac{1}{4}(C - 3)^2)$$
# > #### Onde,
# > #### $n$ - número de observações
# > #### $k$ - número de parâmetros do modelo
# > #### $S$ - Coeficiente de assimetria
# > #### $C$ - Coeficiente de curtose

# %%
# Calcula a estatística de teste de Jarque-Bera, conforme fómula matemática.
JB = (n - 1 / 6.) * (S ** 2 + (1 / 4.) * (C - 3) ** 2)
JB
# Out:
# 23.412056198352765

# %%
# Calcula o p-valor.
p_valor = chi2.sf(JB, 2)
p_valor
# Out:
# 8.243973584285111e-06

# %%
# Verifica se a hipótese é verdadeira.
p_valor <= 0.05
# Out:
# True
